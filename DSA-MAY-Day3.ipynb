# %%
myList = []

# %%
myList1 = ['a','b',15,5.8,True,1955]
myList1
# Out:
# ['a', 'b', 15, 5.8, True, 1955]

# %%
myList1[2]
# Out:
# 15

# %%
len(myList1)
# Out:
# 6

# %%
type(myList1)
# Out:
# list

# %%
myList1[-1]
# Out:
# 1955

# %%
myList1[2:5]
# Out:
# [15, 5.8, True]

# %%
fruits =["apple","orange","grapes","guava","Pineapple"]

# %%
fruits[3]
# Out:
# 'guava'

# %%
fruits[:4]
# Out:
# ['apple', 'orange', 'grapes', 'guava']

# %%
fruits[3] = "Banana"
fruits
# Out:
# ['apple', 'orange', 'grapes', 'Banana', 'Pineapple']

# %%
fruits[1:4] = ["watermelon"]

# %%
fruits
# Out:
# ['apple', 'watermelon', 'Pineapple']

# %%
fruits =["apple","orange","grapes","guava","Pineapple"]

# %%
fruits.append("Papaya")
fruits
# Out:
# ['apple', 'orange', 'grapes', 'guava', 'Pineapple', 'Papaya']

# %%
fruits.insert(2,"Cherry")
fruits
# Out:
# ['apple', 'orange', 'Cherry', 'grapes', 'guava', 'Pineapple', 'Papaya']

# %%
veg = ["onion","carrot","Cabbage"]
fruits.extend(veg)

# %%
fruits
# Out:
# ['apple',
#  'orange',
#  'Cherry',
#  'grapes',
#  'guava',
#  'Pineapple',
#  'Papaya',
#  'onion',
#  'carrot',
#  'Cabbage']

# %%
fruits.insert(2,'Blueberry')
fruits
# Out:
# ['apple',
#  'orange',
#  'Blueberry',
#  'Cherry',
#  'grapes',
#  'guava',
#  'Pineapple',
#  'Papaya',
#  'onion',
#  'carrot',
#  'Cabbage']

# %%
fruits.remove('Pineapple')

# %%
fruits
# Out:
# ['apple',
#  'orange',
#  'Blueberry',
#  'Cherry',
#  'grapes',
#  'guava',
#  'Papaya',
#  'onion',
#  'carrot',
#  'Cabbage']

# %%
fruits.pop()
# Out:
# 'Cabbage'

# %%
fruits
# Out:
# ['apple',
#  'orange',
#  'Blueberry',
#  'Cherry',
#  'grapes',
#  'guava',
#  'Papaya',
#  'onion',
#  'carrot']

# %%
fruits.pop(2)
# Out:
# 'Blueberry'

# %%
fruits
# Out:
# ['apple', 'orange', 'Cherry', 'grapes', 'guava', 'Papaya', 'onion', 'carrot']

# %%
del fruits[1]

# %%
fruits
# Out:
# ['apple', 'Cherry', 'grapes', 'guava', 'Papaya', 'onion', 'carrot']

# %%
fruits.clear()

# %%
fruits
# Out:
# ['apple', 'Cherry', 'grapes', 'guava', 'Papaya', 'onion', 'carrot']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['Cherry', 'Papaya', 'apple', 'carrot', 'grapes', 'guava', 'onion']

# %%
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['onion', 'guava', 'grapes', 'carrot', 'apple', 'Papaya', 'Cherry']

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['Cherry', 'Papaya', 'apple', 'carrot', 'grapes', 'guava', 'onion']

# %%
fruits1 = fruits.copy()
fruits1
# Out:
# ['Cherry', 'Papaya', 'apple', 'carrot', 'grapes', 'guava', 'onion']

# %%
fruits1.clear()

# %%
fruits1
# Out:
# []

# %%
fruits
# Out:
# ['Cherry', 'Papaya', 'apple', 'carrot', 'grapes', 'guava', 'onion']

# %%
li1 =["a","b","c"]
li2 = [14,12,15.6]
li3 = li1+li2

# %%
li3
# Out:
# ['a', 'b', 'c', 14, 12, 15.6]

# %%
li3.reverse()

# %%
li3
# Out:
# [15.6, 12, 14, 'c', 'b', 'a']

# %%
myTuple = ('apple','bleberry','papaya')

# %%
myTuple
# Out:
# ('apple', 'bleberry', 'papaya')

# %%
type(myTuple)
# Out:
# tuple

# %%
newList = list(myTuple)

# %%
newList
# Out:
# ['apple', 'bleberry', 'papaya']

# %%
newList.append("Kiwi")
newList
# Out:
# ['apple', 'bleberry', 'papaya', 'Kiwi']

# %%
myTuple =tuple(newList)

# %%
myTuple
# Out:
# ('apple', 'bleberry', 'papaya', 'Kiwi')

# %%
tup2 = ("hello",)

# %%
type(tup2)
# Out:
# tuple

# %%
tup2
# Out:
# ('hello',)

# %%
del tup2

# %%
tup2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-9d6435f7c59b> in <cell line: 1>()
# ----> 1 tup2
#
# NameError: name 'tup2' is not defined

# %%
tup3 = ("s","t","u")
tup4 =("asd","teer","trte")

tup5 = tup3 + tup4

# %%
tup5
# Out:
# ('s', 't', 'u', 'asd', 'teer', 'trte')

# %%
myDict = {
    "name" : "John",
    "Age" : 35,
    "Color" : "Yellow",
    "Food" : "Burger",
    "Vehicle" : "Mahindra"
}

# %%
myDict['name']
# Out:
# 'John'

# %%
myDict['Color']
# Out:
# 'Yellow'

# %%
myDict['Surname'] = "Abraham"

# %%
myDict
# Out:
# {'name': 'John',
#  'Age': 35,
#  'Color': 'Yellow',
#  'Food': 'Burger',
#  'Vehicle': 'Mahindra',
#  'Surname': 'Abraham'}

# %%
myDict2 = dict(name="Anand",Job="Analyst",Sal=40000)
myDict2
# Out:
# {'name': 'Anand', 'Job': 'Analyst', 'Sal': 40000}

# %%
myDict2.keys()
# Out:
# dict_keys(['name', 'Job', 'Sal'])

# %%
myDict2.values()
# Out:
# dict_values(['Anand', 'Analyst', 40000])

# %%
myDict.items()
# Out:
# dict_items([('name', 'John'), ('Age', 35), ('Color', 'Yellow'), ('Food', 'Burger'), ('Vehicle', 'Mahindra'), ('Surname', 'Abraham')])

# %%
myDict2.update({"Qualification":"BTech",
                "Location":"EKM"})
myDict2
# Out:
# {'name': 'Anand',
#  'Job': 'Analyst',
#  'Sal': 40000,
#  'Qualification': 'BTech',
#  'Location': 'EKM'}

# %%
del myDict2['Location']

# %%
myDict2
# Out:
# {'name': 'Anand', 'Job': 'Analyst', 'Sal': 40000, 'Qualification': 'BTech'}

# %%
del myDict2

# %%
myDict.popitem()
# Out:
# ('Surname', 'Abraham')

# %%
myDict
# Out:
# {'name': 'John',
#  'Age': 35,
#  'Color': 'Yellow',
#  'Food': 'Burger',
#  'Vehicle': 'Mahindra'}

# %%
myDict.pop("Food")
myDict
# Out:
# {'name': 'John', 'Age': 35, 'Color': 'Yellow', 'Vehicle': 'Mahindra'}

# %%
myDict['Color'] = "Red"
myDict
# Out:
# {'name': 'John',
#  'Age': 35,
#  'Color': 'Red',
#  'Food': 'Burger',
#  'Vehicle': 'Mahindra'}

# %%
myDict.update({"Food":"Pizza"})

# %%
myDict
# Out:
# {'name': 'John',
#  'Age': 35,
#  'Color': 'Red',
#  'Food': 'Pizza',
#  'Vehicle': 'Mahindra'}

# %%
fruits2 = ['apple', 'orange', 'Cherry', 'grapes', 'guava', 'Papaya', 'onion', 'carrot']

# %%
for i in fruits2:
  print("I love ",i)
# Out:
# I love  apple
# I love  orange
# I love  Cherry
# I love  grapes
# I love  guava
# I love  Papaya
# I love  onion
# I love  carrot

# %%
for i in range(5):
  print("Hello I am ",i)
# Out:
# Hello I am  0
# Hello I am  1
# Hello I am  2
# Hello I am  3
# Hello I am  4

# %%
mystr = "Welcome to TVM"
strlen = len(mystr)
print(strlen)
# Out:
# 14

# %%
for pos in range(strlen):
  print(mystr[pos])
# Out:
# W
# e
# l
# c
# o
# m
# e
#
# t
# o
#
# T
# V
# M

# %%
for pos in range(1,strlen,2):
  print(mystr[pos])
# Out:
# e
# c
# m
#
# o
# T
# M

# %%
for i in range(2,15,3):
  print(i)
# Out:
# 2
# 5
# 8
# 11
# 14

# %%
fruits2 = ('apple', 'orange', 'Cherry', 'grapes', 'guava', 'Papaya', 'onion', 'carrot')

# %%
for fr in fruits2:
  print(fr)
# Out:
# apple
# orange
# Cherry
# grapes
# guava
# Papaya
# onion
# carrot

# %%
myDict
# Out:
# {'name': 'John',
#  'Age': 35,
#  'Color': 'Red',
#  'Food': 'Pizza',
#  'Vehicle': 'Mahindra'}

# %%
for dic in myDict:
  print(myDict[dic])
# Out:
# John
# 35
# Red
# Pizza
# Mahindra

# %%
for dic in myDict.values():
  print(dic)
# Out:
# John
# 35
# Red
# Pizza
# Mahindra

# %%
for dic in myDict.keys():
  print(dic)
# Out:
# name
# Age
# Color
# Food
# Vehicle

# %%
for x,y in myDict.items():
  print(f"the value for key {x} is {y}")
# Out:
# the value for key name is John
# the value for key Age is 35
# the value for key Color is Red
# the value for key Food is Pizza
# the value for key Vehicle is Mahindra
