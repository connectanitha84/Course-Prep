# %% [markdown]
# A nutritionist claims that the average weight loss of clients following a new diet plan is 5 kg. A sample of 30 clients showed an average weight loss of 4.5 kg with a standard deviation of 1.2 kg. Test the claim at the 5% significance level.

# %% [markdown]
# A smartphone manufacturer claims that the average battery life of its phones is 24 hours with a standard deviation of 2 hours. A sample of 100 phones had an average battery life of 23.5 hours. Test the claim at the 1% significance level.

# %% [markdown]
# A coffee shop claims that the average amount of coffee in its cups is 300 ml. A sample of 20 cups had an average amount of 295 ml with a standard deviation of 10 ml. Test the claim at the 5% significance level.

# %% [markdown]
# A university claims that the average GPA of its students is 3.0. A sample of 15 students had an average GPA of 2.8 with a standard deviation of 0.4. Test the claim at the 5% significance level.

# %% [markdown]
# A pharmaceutical company claims that the average recovery time from a certain illness is 14 days with a standard deviation of 3 days. A sample of 60 patients had an average recovery time of 13 days. Test the claim at the 5% significance level.

# %% [markdown]
# A survey was conducted to find out if there is an association between smoking status and lung disease. The survey results are as follows:**
#
#
# |               | Lung Disease | No Lung Disease |
# |---------------|--------------|-----------------|
# | Smoker        | 40           | 10              |
# | Non-Smoker    | 30           | 50              |
#
#
# Test at the 1% significance level whether there is an association between smoking status and lung disease.

# %% [markdown]
# A study was conducted to determine if a new drug is effective in treating a disease. The results are as follows:**
#
#
# |           | Effective | Not Effective |
# |-----------|-----------|---------------|
# | Drug      | 70        | 30            |
# | Placebo   | 60        | 40            |
#
#
# Test at the 5% significance level whether the new drug is effective.

# %% [markdown]
# A sports center is planning to compare the ages from a random sample of male and
# female swimmers in their coaching center. The swimming coordinator collected 62
# female swimmers’ data, and the mean age is 23.1 with a standard deviation of 3.5.
# Similarly, collected 46 male swimmers data and the mean average is 19.2 with a standard
# deviation of 4.8. Assume the population follows a standard normal distribution. At 5%
# significance level, test whether there is a significant difference in age between the sexes?
#
#
# • Provide justifications for the answer.
# • Specify your null and alternate hypothesis
# • For example, why you rejected/not rejected Ho.
# • Include all necessary steps

# %% [markdown]
# A Little League baseball coach wants to know if his team is representative of other teams
# in scoring runs. Nationally, the average number of runs scored by a Little League team in
# a game is 5.7. He chooses five games at random in which his team scored 5, 9, 4, 11, and
# 8 runs. Is it likely that his team's scores could have come from the national distribution?
# Assume an alpha level of 0.05.
#
#
# • Provide justifications for the answer.
# • Specify your null and alternate hypothesis
# • For example, why you rejected/not rejected Ho.
# • Include all necessary steps
