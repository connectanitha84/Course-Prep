# %%
# Ask the user for different words
tech_company = input("Enter a well-known tech company: ")
food = input("Enter a food you wouldn't expect to find at work: ")
celebrity_chef =  input("Enter a celebrity chef: ")
skill = input("Enter a random skill (e.g., juggling, origami): ")
adjective = input("Enter an adjective describing a robot: ")

# Create a funny story template
story = f"""At {tech_company}'s headquarters, a new employee benefit was unveiled today: a daily lunch prepared by {celebrity_chef} himself!
The menu featured some unusual options, including {food}.  However, the most surprising addition was a team of {adjective} robots programmed to teach employees new skills,
like {skill}.  Many were skeptical, but after a delightful lunch and a surprisingly engaging {skill} lesson, the mood was positive.
It seems {tech_company} is taking employee well-being and skill development to a whole new level!"""

# Print the completed story
print(story)
# Out:
# Enter a well-known tech company: INFOSYS
# Enter a food you wouldn't expect to find at work: DUM BIRIYANI
# Enter a celebrity chef: suresh pillai
# Enter a random skill (e.g., juggling, origami): juggling
# Enter an adjective describing a robot: cute
# At INFOSYS's headquarters, a new employee benefit was unveiled today: a daily lunch prepared by suresh pillai himself!
# The menu featured some unusual options, including DUM BIRIYANI.  However, the most surprising addition was a team of cute robots programmed to teach employees new skills,
# like juggling.  Many were skeptical, but after a delightful lunch and a surprisingly engaging juggling lesson, the mood was positive.
# It seems INFOSYS is taking employee well-being and skill development to a whole new level!

# %%
# Ask the user for different words
tech_company = input("Enter a well-known tech company (e.g., Google, Apple): ")
movie_genre = input("Enter a movie genre (e.g., sci-fi, comedy): ")
literary_device = input("Enter a literary device (e.g., metaphor, simile): ")
natural_wonder = input("Enter a natural wonder (e.g., Grand Canyon, Great Barrier Reef): ")
food_item = input("Enter a surprisingly healthy food (e.g., kale, black beans): ")

# Create a funny story template
story = f"""Scientists at {tech_company} recently announced a breakthrough in {movie_genre} technology.
 They've created a device that allows you to experience a book {literary_device}.
 Imagine feeling the wind whipping through your hair as you explore the depths of the {natural_wonder}
 just like your favorite literary hero!

However, there's a catch. To activate the device, you must first consume a healthy portion of {food_item}.
 Apparently, brainwaves function better on a diet rich in vitamins and fiber. Who knew saving the world
 (or at least getting lost in a good book) could be so healthy?"""

# Print the completed story
print(story)
