# %%
print('Hello Everyone!!! Welcome to the session')
# Out:
# Hello Everyone!!! Welcome to the session

# %%
print(2024)
# Out:
# 2024

# %%
print('2024')
# Out:
# 2024

# %%
#this is a comment
#this is a comment
#this is a comment
#this is a comment
#this is a comment
"""
sdfadsfasdfasdfads
sdfadsfasdfasdfads
sdfadsfasdfasdfads
"""

print("python class 1")
# Out:
# python class 1

# %%
age = 25

x = 123

newText = "Python"

language = "English"

print(language)
# Out:
# English

# %%
print(AGE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8f9bf652ef59> in <cell line: 1>()
# ----> 1 print(AGE)
#
# NameError: name 'AGE' is not defined

# %%
name = "Philip"
year = 1995

print(name)
# Out:
# Philip

# %%
print("My name is ",name)
# Out:
# My name is  Philip

# %%
print(f"Hi I am {name} and I was born in {year}")
# Out:
# Hi I am Philip and I was born in 1995

# %%
print("{0} is my name and I was born in {1} and I am from {2}".format(name,year,"Trivandrum"))
# Out:
# Philip is my name and I was born in 1995 and I am from Trivandrum

# %%
print(name,end='@experts')
# Out:
# Philip@experts

# %%
print('hello','world',sep="_",end="@")
# Out:
# hello_world@

# %%
input("ENTER your name?")
# Out:
# ENTER your name?anitha
# 'anitha'

# %%
name1 = input("ENTER your name?")
# Out:
# ENTER your name?asha

# %%
print(name1)
# Out:
# asha

# %%
tech_company = input("enter your company")
food =input("Enter your favourite food")
skill = input("enter your skill")

print(f"my company is {tech_company} , my favourite food is {food} , and my skill is {skill}")
# Out:
# enter your companyInfosys
# Enter your favourite foodDum biriyani
# enter your skillpython programming
# my company is Infosys , my favourite food is Dum biriyani , and my skill is python programming

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
height = 180.7
print(type(height))
# Out:
# <class 'float'>

# %%
year = "2021"
year1 = 2023

print(type(year))
print(type(year1))
# Out:
# <class 'str'>
# <class 'int'>

# %%
tech_company = input("enter your company")

experience = int(input("enter your experience"))

print(type(tech_company))
print(type(experience))
# Out:
# enter your companyust
# enter your experience8
# <class 'str'>
# <class 'int'>

# %%
newStr = "India is my Country."
newStr
# Out:
# 'India is my Country.'

# %%
len(newStr)
# Out:
# 20

# %%
#newStr[start:end:stop]

newStr[2:10]
# Out:
# 'dia is m'

# %%
newStr[2:20:4]
# Out:
# 'diyuy'

# %%
newStr[5:]
# Out:
# ' is my Country.'

# %%
newStr[:10]
# Out:
# 'India is m'

# %%
newStr.upper()
# Out:
# 'INDIA IS MY COUNTRY.'

# %%
newStr.lower()
# Out:
# 'india is my country.'

# %%
newStr.capitalize()
# Out:
# 'India is my country.'

# %%
newStr[2]
# Out:
# 'd'

# %%
newStr[-2]
# Out:
# 'y'

# %%
5+2
# Out:
# 7

# %%
3*7
# Out:
# 21

# %%
15%4
# Out:
# 3

# %%
17//4
# Out:
# 4

# %%
4**3
# Out:
# 64

# %%
a = 5
b = 10

# %%
a> b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
print((a>2) and (b<10))
# Out:
# False
