# %% [markdown]
# **this is my first day in Data Science Class**

# %%
10
# Out:
# 10

# %%
5+10
# Out:
# 15

# %%
5*3
# Out:
# 15

# %%
20/4
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
8%5
# Out:
# 3

# %%
2**2
# Out:
# 4

# %%
5**3
# Out:
# 125

# %%
print("hello")
# Out:
# hello

# %%
#This is a comment
#This is a comment
#This is a comment
#This is a comment
"""
this is a multi line comment
this is a multi line comment
this is a multi line comment
this is a multi line comment

"""
print("Hello", "World",sep="\n")
# Out:
# Hello
# World

# %%
print("Hello","world", end="#####")
# Out:
# Hello world#####

# %%
name = "Joseph"
age = 54
print(f"Hello, {name}. You are {age}.")
# Out:
# Hello, Joseph. You are 54.

# %%
print('{0} {1} cost ${2}'.format(6, 'bananas', 1.74))
# Out:
# 6 bananas cost $1.74

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f327648c8dd0> in <cell line: 1>()
# ----> 1 print('{1} is my name and {2} is my age',format("Akshay",18))
#
# TypeError: format() argument 2 must be str, not int

# %%
print("Total students : %3d, Boys : %2d" % (240, 120))
# Out:
# Total students : 240, Boys : 120

# %%
length = 5
breadth = 13
area = length * breadth

# %%
print("Rectangle area is ",area)
# Out:
# Rectangle area is  65

# %%
x = 10

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
y = 13.56
print(type(y))
# Out:
# <class 'float'>

# %%
z = int(y)

# %%
print(z)
# Out:
# 13

# %%
FirstNo = int(input("Enter the first number\n"))
SecondNo = int(input("Enter the second number\n"))
Total = FirstNo + SecondNo
print("Total is",Total)
# Out:
# Enter the first number
# 100
# Enter the second number
# 200
# Total is 300

# %%
print('python '*5)
# Out:
# python python python python python

# %%
print('python\n'*5)
# Out:
# python
# python
# python
# python
# python

# %%
newString = "United States"
newString[0]
# Out:
# 'U'

# %%
newString[-1]
# Out:
# 's'

# %%
len(newString)
# Out:
# 13

# %%
newString[:4]
# Out:
# 'Unit'

# %%
newString[4:]
# Out:
# 'ed States'

# %%
newString[2:9]
# Out:
# 'ited St'

# %%
newString[2:9:2]
# Out:
# 'ie t'

# %%
newString.upper()
# Out:
# 'UNITED STATES'

# %%
newString.lower()
# Out:
# 'united states'

# %%
newString.capitalize()
# Out:
# 'United states'

# %%
newString.swapcase()
# Out:
# 'uNITED sTATES'

# %%
print(100 + 5 * 3)
