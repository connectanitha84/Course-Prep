# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Matplotlib is a Python library that helps in visualizing and analyzing the data and helps in better understanding of the data with the help of graphical, pictorial visualizations that can be simulated using the matplotlib library. Matplotlib is a comprehensive library for static, animated and interactive visualizations.

# %%
# importing the required module
import matplotlib.pyplot as plt

# x axis values
x = [1,2,3]
# corresponding y axis values
y = [2,4,1]

# plotting the points
plt.plot(x, y)

# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')

# giving a title to my graph
plt.title('My first graph!')

# function to show the plot
plt.show()

# %% [markdown]
# The code seems self-explanatory. Following steps were followed:
#
# Define the x-axis and corresponding y-axis values as lists.
# Plot them on canvas using .plot() function.
# Give a name to x-axis and y-axis using .xlabel() and .ylabel() functions.
# Give a title to your plot using .title() function.
# Finally, to view your plot, we use .show() function.

# %%
import matplotlib.pyplot as plt

# initializing the data
x = [10, 20, 30, 40]
y = [20, 30, 40, 50]

# plotting the data
plt.plot(x, y)

# Adding the title
plt.title("Simple Plot")

# Adding the labels
plt.ylabel("y-axis")
plt.xlabel("x-axis")
plt.show()

# %% [markdown]
# Pyplot is a Matplotlib module that provides a MATLAB-like interface. Pyplot provides functions that interact with the figure i.e. creates a figure, decorates the plot with labels, and creates a plotting area in a figure.

# %%
import matplotlib.pyplot as plt

# data to display on plots
x = [3, 1, 3]
y = [3, 2, 1]
plt.plot(x, y)
plt.plot(y, x)

# Adding the legends
plt.legend(["blue", "orange"])
plt.show()

# %%
# using Numpy to process data and then pass it to matplotlib for plotting
x = np.arange(0,100)
y = 9 * x + 7 #mx+c equation for straight line

plt.plot(x,y)
plt.show()

# %%
x1 = [6, 9, 11]
y1 = [13, 17, 7]

x2 = [7, 10, 12]
y2 = [7, 16, 8]

# Mupltiple plots in same graph
plt.plot(x1,y1)
plt.plot(x2, y2)

# add color and label
plt.plot(x1,y1, c="g", label='line 1')
plt.plot(x2, y2, c="b", label='line 2')
plt.legend() # Place a legend on the Axes

# %%
plt.plot(x1,y1, c="g", label='line 1')
plt.plot(x2, y2, c="b", label='line 2')
plt.xlim(5,20) # Defines the limit to x axis
plt.ylim(0,20) # Defines the limit to y axis
plt.legend() # Place a legend on the Axes

# %% [markdown]
# Following line styles are available in Matplotlib
# Character
#
# Definition
#
# –
#
# Solid line
#
# —
#
# Dashed line
#
# -.
#
# dash-dot line
#
# :
#
# Dotted line
#
# .
#
# Point marker
#
# o
#
# Circle marker
#
# ,
#
# Pixel marker
#
# v
#
# triangle_down marker
#
# ^
#
# triangle_up marker
#
# <
#
# triangle_left marker
#
# >
#
# triangle_right marker
#
# 1
#
# tri_down marker
#
# 2
#
# tri_up marker
#
# 3
#
# tri_left marker
#
# 4
#
# tri_right marker
#
# s
#
# square marker
#
# p
#
# pentagon marker
#
# *
#
# star marker
#
# h
#
# hexagon1 marker
#
# H
#
# hexagon2 marker
#
# +
#
# Plus marker
#
# x
#
# X marker
#
# D
#
# Diamond marker
#
# d
#
# thin_diamond marker
#
# |
#
# vline marker
#
# _
#
# hline marker
#
# Color code abbreviations that can be used along with the line styles:
#
# Codes
#
# Description
#
# b
#
# blue
#
# g
#
# green
#
# r
#
# red
#
# c
#
# cyan
#
# m
#
# magenta
#
# y
#
# yellow
#
# k
#
# black
#
# w
#
# white

# %%
import matplotlib.pyplot as plt
import random as random

students = ["Jane","Joe","Beck","Tom","Liam","Culhane",
            "Candance","Ana","Mari","Steffi","Adam"]

marks=[]
for i in range(0,len(students)):
     marks.append(random.randint(0, 101))


plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("CLASS RECORDS")

plt.xticks(rotation=90)
plt.plot(students, marks, color = 'k',
         linestyle = 'dashed', marker = 'o',
         markerfacecolor = 'c', markersize = 8, markeredgecolor = 'r')

# %%
# To plot multiple horizontal lines, use the axhline() method multiple times.

import matplotlib.pyplot as plt

# plotting line within the given range
plt.axhline(y = .5, xmin = 0.25, xmax = 0.9)

# line colour is blue
plt.axhline(y = 3, color = 'b', linestyle = ':')

# line colour is white
plt.axhline(y = 1, color = 'w', linestyle = '--')

# line colour is red
plt.axhline(y = 2, color = 'r', linestyle = 'dashed')

# adding axis labels
plt.xlabel('x - axis')
plt.ylabel('y - axis')

# displaying the plot
plt.show()

# %%
# verticl lines (1) using axvline

# importing the modules
import matplotlib.pyplot as plt
import numpy as np

# specifying the plot size
plt.figure(figsize = (10, 5))

# only one line may be specified; full height
plt.axvline(x = 7, color = 'b', label = 'axvline - full height')

# rendering plot
plt.show()

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# defining an array
xs = [1, 100]

# defining plot size
plt.figure(figsize = (5,5))

# single line
plt.vlines(x = 37, ymin = 0, ymax = max(xs),
           colors = 'purple',
           label = 'vline_multiple - full height')

plt.show()

# %% [markdown]
# Creating a bar plot

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (8, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# Horizontal bar chart

# %%
import matplotlib.pyplot as plt
y=['one', 'two', 'three', 'four', 'five']

# getting values against each value of y
x=[5,24,35,67,12]
plt.barh(y, x)

# setting label of y-axis
plt.ylabel("pen sold")

# setting label of x-axis
plt.xlabel("price")
plt.title("Horizontal bar graph")
plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
# import required module
import matplotlib.pyplot as plt

# first data point
x = [1, 2, 3, 4]
y = [4, 1, 3, 6]

# depict first scatted plot
plt.scatter(x, y, c='green')

# second data point
x = [5, 6, 7, 8]
y = [1, 3, 5, 2]

# depict second scatted plot
plt.scatter(x, y, c='red')

# depict illustration
plt.show()

# %%
fig,ax=plt.subplots(1,2,sharey=True)
ax[0].plot(x,y)
ax[0].set_title('Line chart ')
ax[1].scatter(x,y)
ax[1].set_title('scatter chart')
# Out:
# Text(0.5, 1.0, 'scatter chart of immigrants')

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np

# Creating dataset
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']

data = [23, 17, 35, 29, 12, 41]
explode=[0.1, 0, 0, 0,0.1,0]

# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars,explode=explode)
plt.title("Car sold")


# show plot
plt.show()

# %%
cars = ['BMW','FORD','TESLA','MERCEDES','AUDI','JAGUAR']
sales = [25,17,35,29,12,41]
colors=['skyblue', 'lightgreen', 'lightcoral','orange','yellow','cyan']
explode = (0.1,0,0,0.1,0,0)
labels = [f'{car}:{sale}' for car,sale in zip(cars,sales)]
plt.pie(sales,labels=labels,autopct='%1.1f%%',colors=colors,explode=explode,shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
x = np.arange(1, 6)
y1 = np.array([1, 4, 9, 16, 25])
y2 = np.array([1, 2, 4, 8, 16])
y3 = np.array([5, 7, 3, 9, 11])
y4 = np.array([10, 8, 6, 4, 2])

# Create subplots with 2 rows and 2 columns
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 8))

# Plot on the first subplot (ax1)
ax1.plot(x, y1, marker='o', color='skyblue', label='Line 1')
ax1.set_title('Subplot 1')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')
ax1.legend()
ax1.grid(True)

# Set xticks with rotation for the first subplot
ax1.set_xticks(x)
ax1.set_xticklabels(['A', 'B', 'C', 'D', 'E'], rotation=45)  # Rotates labels by 45 degrees

# Plot on the second subplot (ax2)
ax2.plot(x, y2, marker='s', color='lightgreen', label='Line 2')
ax2.set_title('Subplot 2')
ax2.set_xlabel('X-axis')
ax2.set_ylabel('Y-axis')
ax2.legend()
ax2.grid(True)

# Set xticks with rotation for the second subplot
ax2.set_xticks(x)
ax2.set_xticklabels(['One', 'Two', 'Three', 'Four', 'Five'], rotation=45)  # Rotates labels by 45 degrees

# Plot on the third subplot (ax3)
ax3.plot(x, y3, marker='^', color='orange', label='Line 3')
ax3.set_title('Subplot 3')
ax3.set_xlabel('X-axis')
ax3.set_ylabel('Y-axis')
ax3.legend()
ax3.grid(True)

# Set xticks with rotation for the third subplot
ax3.set_xticks(x)
ax3.set_xticklabels(['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon'], rotation=45)  # Rotates labels by 45 degrees

# Plot on the fourth subplot (ax4)
ax4.plot(x, y4, marker='d', color='purple', label='Line 4')
ax4.set_title('Subplot 4')
ax4.set_xlabel('X-axis')
ax4.set_ylabel('Y-axis')
ax4.legend()
ax4.grid(True)

# Set xticks with rotation for the fourth subplot
ax4.set_xticks(x)
ax4.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May'], rotation=45)  # Rotates labels by 45 degrees

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/medals_by_country_2016.csv')
data.head()

# %%
data = data.rename(columns={'Unnamed: 0':'Country'})
data.head()

# %%
plt.title('Countries with Gold Medal')
plt.xlabel("Country")
plt.ylabel("Medals")
plt.xticks(rotation=45)
plt.bar(data['Country'],data['Gold'])

# %%
plt.boxplot(data['Silver'])

# %%
data.describe()

# %%
plt.boxplot(data['Gold'])

# %%
x=[0,1,2,3]
y=[3,8,1,10]


x1=[0,1,2,3]
y1=[10,20,30,40]


x3 = [0,1,2,3]
y3 = [10,20,30,40]

fig=plt.figure(figsize=(10,7))
plt.subplot(1,3,1)
plt.plot(data['Country'],data['Gold'])
plt.xticks(rotation=45)
plt.title('Line chart')


plt.subplot(1,3,2)
plt.xticks(rotation=90)
plt.bar(data['Country'],data['Silver'])
plt.title('bar chart')


plt.subplot(1,3,3)
plt.scatter(data['Gold'],data['Silver'])
plt.title('Scatter chart')


plt.suptitle("Multiple Charts")

# %%
data[['Gold','Silver', 'Bronze']].plot.bar()

# %% [markdown]
# iris data - scatter plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Display the first few rows of the dataset
print(iris.head())

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='petal_length', y='petal_width', hue='species', palette='viridis',data=iris,  s=100)
plt.title('Petal Length vs. Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Species')
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# iris data- subplots

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Iris dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris = pd.read_csv(url)

# Scatter plot: Sepal Length vs Sepal Width
plt.figure(figsize=(8, 6))
plt.scatter(iris['sepal_length'], iris['sepal_width'], c=iris['species'].astype('category').cat.codes, cmap='viridis')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.colorbar(label='Species')
plt.grid(True)
plt.show()

# Bar plot: Average Petal Length by Species
avg_petal_length = iris.groupby('species')['petal_length'].mean()
plt.figure(figsize=(8, 6))
avg_petal_length.plot(kind='bar', color=['skyblue', 'lightgreen', 'lightcoral'])
plt.title('Average Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Average Petal Length (cm)')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# Histogram: Distribution of Petal Width
plt.figure(figsize=(8, 6))
plt.hist(iris['petal_width'], bins=20, color='lightblue', edgecolor='black')
plt.title('Histogram of Petal Width')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# IRIS DATASET USING SEABORN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris = pd.read_csv(url)

# Set style for seaborn plots
sns.set(style="whitegrid")

# Plot 1: Pairplot (Scatter plot matrix)
sns.pairplot(iris, hue='species', height=3)
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()

# Plot 2: Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='sepal_length', data=iris)
plt.title('Boxplot of Sepal Length by Species')
plt.show()

# Plot 3: Violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile')
plt.title('Violin Plot of Petal Length by Species')
plt.show()

# Plot 4: Histograms for each feature
plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
sns.histplot(iris['sepal_length'], bins=20, kde=True)
plt.title('Histogram of Sepal Length')

plt.subplot(2, 2, 2)
sns.histplot(iris['sepal_width'], bins=20, kde=True)
plt.title('Histogram of Sepal Width')

plt.subplot(2, 2, 3)
sns.histplot(iris['petal_length'], bins=20, kde=True)
plt.title('Histogram of Petal Length')

plt.subplot(2, 2, 4)
sns.histplot(iris['petal_width'], bins=20, kde=True)
plt.title('Histogram of Petal Width')

plt.tight_layout()
plt.show()

# Plot 5: Pie chart of species distribution
species_counts = iris['species'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'lightcoral'])
plt.title('Distribution of Iris Species')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Initialize the figure
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Scatter plot: Sepal Length vs Sepal Width
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris, ax=axs[0, 0])
axs[0, 0].set_title('Sepal Length vs Sepal Width')

# Scatter plot: Petal Length vs Petal Width
sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=iris, ax=axs[0, 1])
axs[0, 1].set_title('Petal Length vs Petal Width')

# Box plot: Sepal Length
sns.boxplot(x='species', y='sepal_length', data=iris, ax=axs[1, 0])
axs[1, 0].set_title('Sepal Length by Species')

# Box plot: Petal Length
sns.boxplot(x='species', y='petal_length', data=iris, ax=axs[1, 1])
axs[1, 1].set_title('Petal Length by Species')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation matrix
iris_numeric=iris[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
correlation_matrix = iris_numeric.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Iris Dataset')
plt.show()
