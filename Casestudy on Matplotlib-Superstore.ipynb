# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('/content/Sample - Superstore.xlsx')
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date Customer ID       Ship Mode  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    CG-12520    Second Class
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    CG-12520    Second Class
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    DV-13045    Second Class
# 3       4  US-2016-108966 2016-10-11 2016-10-18    SO-20335  Standard Class
# 4       5  US-2016-108966 2016-10-11 2016-10-18    SO-20335  Standard Class
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Customer ID',
#        'Ship Mode', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Customer ID    9994 non-null   object
#  5   Ship Mode      9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
plt.bar(data['Category'], data['Sales'])
plt.show()

# %%
plt.bar(data['Category'], data['Profit'])
plt.show()

# %%
plt.bar(data['Sub-Category'], data['Sales'])
plt.show()

# %%
plt.bar(data['Sub-Category'], data['Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.boxplot(data['Sales'])
plt.show()

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
plt.bar(data['Segment'], data['Sales'])
plt.show()

# %%
plt.bar(data['Segment'], data['Profit'],width=0.4)
plt.show()

# %%
plt.hist(data['Sales'])
plt.show()

# %%
plt.hist(data['Sales'])
plt.xlim(-100,5000)
plt.show()

# %%
plt.hist(data['Profit'])
plt.show()

# %%
plt.hist(data['Profit'])
plt.xlim(-3000,3000)
plt.show()

# %%
print(data['State'].unique())
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
print(data['State'].nunique())
# Out:
# 49

# %%
# Creating a new df with loss values
loss_df = data[data['Profit'] < 0]
loss_df.shape
# Out:
# (1871, 21)

# %% [markdown]
# ##### We can see that there are 9994 rows in the overall superstore Dataframe. Now we have only 1871 rows that are related to loss.
# ##### More discount leads to more loss, so, to make more profit provide fewer discounts.

# %%
loss_df.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date Customer ID       Ship Mode  \
# 3        4  US-2016-108966 2016-10-11 2016-10-18    SO-20335  Standard Class
# 14      15  US-2016-118983 2016-11-22 2016-11-26    HP-14815  Standard Class
# 15      16  US-2016-118983 2016-11-22 2016-11-26    HP-14815  Standard Class
# 23      24  US-2018-156909 2018-07-16 2018-07-18    SF-20065    Second Class
# 27      28  US-2016-150630 2016-09-17 2016-09-21    TB-21520  Standard Class
#
#       Customer Name      Segment        Country             City  ...  \
# 3    Sean O'Donnell     Consumer  United States  Fort Lauderdale  ...
# 14    Harold Pawlan  Home Office  United States       Fort Worth  ...
# 15    Harold Pawlan  Home Office  United States       Fort Worth  ...
# 23  Sandra Flanagan     Consumer  United States     Philadelphia  ...
# 27  Tracy Blumstein     Consumer  United States     Philadelphia  ...
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
total_loss = loss_df['Profit'].sum()
total_loss
# Out:
# -156131.2857

# %%
total_loss = np.negative( loss_df['Profit'].sum())
total_loss

# np.negative is a NumPy function that returns the negative value of the input.
#  It is equivalent to using the - operator with a scalar or array. Here's how you can use np.negative:
# Out:
# 156131.2857

# %%
loss_df.groupby(by='Segment').sum(numeric_only=True)
# Out:
#               Row ID  Postal Code        Sales  Quantity  Discount      Profit
# Segment
# Consumer     5101571   57202260.0  247196.2460      3651    476.76 -84945.7112
# Corporate    2927896   30034273.0  131860.5383      2191    272.00 -44787.2076
# Home Office  1557473   17522858.0   89650.3705      1198    150.98 -26398.3669

# %%
loss_df.groupby(by='Sub-Category').mean(numeric_only=True)
# Out:
#                    Row ID   Postal Code        Sales  Quantity  Discount  \
# Sub-Category
# Accessories   5485.417582  58092.109890   120.426374  3.626374  0.200000
# Appliances    5302.895522  72027.925373    50.485582  3.507463  0.800000
# Binders       5026.986949  53196.247961    58.956954  4.006525  0.738010
# Bookcases     5293.779817  58931.247706   441.034319  3.871560  0.348532
# Chairs        5257.021277  63863.936170   391.440238  3.727660  0.261277
# Fasteners     5121.250000  58494.166667    12.440000  4.583333  0.200000
# Furnishings   5425.724551  65694.089820    76.921222  3.574850  0.530539
# Machines      4761.954545  50824.113636  1646.733023  3.568182  0.581818
# Phones        5112.463235  44891.867647   263.219412  3.500000  0.342647
# Storage       5091.074534  53456.366460   235.211627  3.534161  0.200000
# Supplies      4523.212121  53376.666667   426.278061  3.333333  0.200000
# Tables        4912.349754  50364.551724   517.135695  3.729064  0.365271
#
# ...

# %% [markdown]
# ##### We can observe more loss in the Binders category, machines category, and tables category when compared to other categories.
# ##### Binders are more getting sold. So even giving less discount may lead to vast loss.
# ##### So better to give discounts on which are getting less sold so that even they will start getting sold more.

# %%
loss_df.groupby(by='City').sum(numeric_only=True).sort_values('Profit',ascending=True).head(5)
# Out:
#                Row ID  Postal Code       Sales  Quantity  Discount      Profit
# City
# Philadelphia  1209769    4783713.0  70460.5510       892    115.30 -19590.7411
# Houston        985125   14256474.0  37640.7304       683    104.14 -14785.3668
# Chicago        769944    9397492.0  19910.0120       541     88.20 -11120.6271
# San Antonio    172970    2580831.0  17395.1450       139     17.10  -7831.0254
# Lancaster      125296     683904.0   7699.2420        71      9.40  -7632.4946

# %%
loss_df.sort_values(['Sales'],ascending=True).groupby(by='Category').mean(numeric_only=True)
# Out:
#                       Row ID   Postal Code       Sales  Quantity  Discount  \
# Category
# Furniture        5204.096639  59700.907563  361.184295  3.714286  0.367143
# Office Supplies  5042.010158  54746.056433  103.395796  3.865688  0.617607
# Technology       5180.789668  50287.590406  439.899974  3.553506  0.333579
#
#                      Profit
# Category
# Furniture        -85.344690
# Office Supplies  -63.899840
# Technology      -142.361322

# %%
# result = loss_df.groupby('Category')['Sales'].sum().sort_values('Sales', ascending=False)
# loss_df.groupby(by='Category')['Sales'].sum()

# loss_df.groupby('Category')['Sales'].sum().reset_index(name='Total Sales').sort_values('Total Sales', ascending=False)

loss_df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Furniture          257885.5868
# Technology         119212.8930
# Office Supplies     91608.6750
# Name: Sales, dtype: float64

# %%
loss_df
# Out:
#       Row ID        Order ID Order Date  Ship Date Customer ID  \
# 3          4  US-2016-108966 2016-10-11 2016-10-18    SO-20335
# 14        15  US-2016-118983 2016-11-22 2016-11-26    HP-14815
# 15        16  US-2016-118983 2016-11-22 2016-11-26    HP-14815
# 23        24  US-2018-156909 2018-07-16 2018-07-18    SF-20065
# 27        28  US-2016-150630 2016-09-17 2016-09-21    TB-21520
# ...      ...             ...        ...        ...         ...
# 9920    9921  CA-2017-149272 2017-03-15 2017-03-19    MY-18295
# 9921    9922  CA-2015-111360 2015-11-24 2015-11-30    AT-10435
# 9931    9932  CA-2016-104948 2016-11-13 2016-11-17    KH-16510
# 9937    9938  CA-2017-164889 2017-06-03 2017-06-06    CP-12340
# 9962    9963  CA-2016-168088 2016-03-19 2016-03-22    CM-12655
#
#            Ship Mode     Customer Name      Segment        Country  \
# 3     Standard Class    Sean O'Donnell     Consumer  United States
# 14    Standard Class     Harold Pawlan  Home Office  United States
# ...

# %%
bar_width = 0.6
sns.countplot(x=data.Segment,color='red')
plt.show()

# %%
plt.figure(figsize=(15,6))
# sns.countplot(x='Sub-Category',data=data,palette='Set3')
# plt.show()
sns.countplot(x='Sub-Category', hue='Sub-Category', data=data, palette='Accent', legend=False)
plt.show()

# Set1, Set2, Set3: Pastel1, Pastel2: Dark2: ,Accent: , Paired:

# %%
palette = sns.color_palette("husl", 4)  # 4 different colors for the 4 regions
# sns.countplot(x='Region',data=data)
sns.countplot(x='Region', hue = 'Region', data=data, palette=palette)
plt.show()
