# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(dtype="int64")
print(ser)
# Out:
# Series([], dtype: int64)

# %%
data = np.array(['ab','cd','ef','gh','mn'])
ser1 = pd.Series(data)
print(ser1)
# Out:
# 0    ab
# 1    cd
# 2    ef
# 3    gh
# 4    mn
# dtype: object

# %%
ser1[3]
# Out:
# 'gh'

# %%
ser1 = pd.Series(data,index=[101,102,103,104,105])
print(ser1)
# Out:
# 101    ab
# 102    cd
# 103    ef
# 104    gh
# 105    mn
# dtype: object

# %%
ser1[103]
# Out:
# 'ef'

# %%
list1 = ["hi","hello","how","are","you"]
ser3 =pd.Series(list1)
ser3
# Out:
# 0       hi
# 1    hello
# 2      how
# 3      are
# 4      you
# dtype: object

# %%
ser3.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
dict1 = {'name':'Amal','age':22,'place':'ekm'}
ser4 = pd.Series(dict1)
ser4
# Out:
# name     Amal
# age        22
# place     ekm
# dtype: object

# %%
ser4['place']
# Out:
# 'ekm'

# %%
ser4.values
# Out:
# array(['Amal', 22, 'ekm'], dtype=object)

# %%
ser4.index
# Out:
# Index(['name', 'age', 'place'], dtype='object')

# %%
ser3[3]
# Out:
# 'are'

# %%
ser3[[3,4]]
# Out:
# 3    are
# 4    you
# dtype: object

# %%
city1 = pd.Series([12,-6,8,-3],index=['day1','day2','day3','day4'])
city1
# Out:
# day1    12
# day2    -6
# day3     8
# day4    -3
# dtype: int64

# %%
city1 >0
# Out:
# day1     True
# day2    False
# day3     True
# day4    False
# dtype: bool

# %%
city1.min()
# Out:
# -6

# %%
city1.max()
# Out:
# 12

# %%
city1>8
# Out:
# day1     True
# day2    False
# day3    False
# day4    False
# dtype: bool

# %%
city1[city1>8]
# Out:
# day1    12
# dtype: int64

# %%
city1[(city1>2) & (city1<9)]
# Out:
# day3    8
# dtype: int64

# %%
city1+3
# Out:
# day1    15
# day2    -3
# day3    11
# day4     0
# dtype: int64

# %%
city1*3
# Out:
# day1    36
# day2   -18
# day3    24
# day4    -9
# dtype: int64

# %%
data = {'Kerala':28,"Andhra":25,"Karnataka":19,"TN":31,"Delhi":38}
data_ser = pd.Series(data)
data_ser
# Out:
# Kerala       28
# Andhra       25
# Karnataka    19
# TN           31
# Delhi        38
# dtype: int64

# %%
states = ['Andhra',"Delhi",'TN','Karnataka','MP','Goa','Kerala']
city2 = pd.Series(data_ser,index=states,dtype='int64')
city2
# Out:
# Andhra       25.0
# Delhi        38.0
# TN           31.0
# Karnataka    19.0
# MP            NaN
# Goa           NaN
# Kerala       28.0
# dtype: float64

# %%
city2.isna()
# Out:
# Andhra       False
# Delhi        False
# TN           False
# Karnataka    False
# MP            True
# Goa           True
# Kerala       False
# dtype: bool

# %%
city2.notna()
# Out:
# Andhra        True
# Delhi         True
# TN            True
# Karnataka     True
# MP           False
# Goa          False
# Kerala        True
# dtype: bool

# %%
city2.isna().sum()
# Out:
# 2

# %%
city2.loc['Kerala']
# Out:
# 28.0

# %%
city2.iloc[2]
# Out:
# 31.0

# %%
city2.iloc[2:5]
# Out:
# TN           31.0
# Karnataka    19.0
# MP            NaN
# dtype: float64

# %%
# .head( ) , .tail()

city2.head(2)
# Out:
# Andhra    25.0
# Delhi     38.0
# dtype: float64

# %%
city2.tail(3)
# Out:
# MP         NaN
# Goa        NaN
# Kerala    28.0
# dtype: float64

# %%
#Dataframe

# %%
data = {'Year':[2001,2002,2004,2005,2006],
        'States':['Kerala','TN','Andhra', 'Karnataka', 'Bihar'],
        'Pop':[300,250,280,400,360]}

pop_data = pd.DataFrame(data)
pop_data
# Out:
#    Year     States  Pop
# 0  2001     Kerala  300
# 1  2002         TN  250
# 2  2004     Andhra  280
# 3  2005  Karnataka  400
# 4  2006      Bihar  360

# %%
pop_data1 = pd.DataFrame(data,columns=['Year','States','Pop','Income'])
pop_data1
# Out:
#    Year     States  Pop Income
# 0  2001     Kerala  300    NaN
# 1  2002         TN  250    NaN
# 2  2004     Andhra  280    NaN
# 3  2005  Karnataka  400    NaN
# 4  2006      Bihar  360    NaN

# %%
pop_data1['Debt'] = [320,420,850,620,140]
pop_data1
# Out:
#    Year     States  Pop Income  Debt
# 0  2001     Kerala  300    NaN   320
# 1  2002         TN  250    NaN   420
# 2  2004     Andhra  280    NaN   850
# 3  2005  Karnataka  400    NaN   620
# 4  2006      Bihar  360    NaN   140

# %%
pop_data1['States']
# Out:
# 0       Kerala
# 1           TN
# 2       Andhra
# 3    Karnataka
# 4        Bihar
# Name: States, dtype: object

# %%
pop_data1.iloc[1]
# Out:
# Year      2002
# States      TN
# Pop        250
# Income     NaN
# Debt       420
# Name: 1, dtype: object

# %%
pop_data1['Income'] = [20000,32000,25000,650000,10000]
pop_data1
# Out:
#    Year     States  Pop  Income  Debt
# 0  2001     Kerala  300   20000   320
# 1  2002         TN  250   32000   420
# 2  2004     Andhra  280   25000   850
# 3  2005  Karnataka  400  650000   620
# 4  2006      Bihar  360   10000   140

# %%
pop_data1['savings'] = pop_data1['Income'] - pop_data1['Debt']
pop_data1
# Out:
#    Year     States  Pop  Income  Debt  savings
# 0  2001     Kerala  300   20000   320    19680
# 1  2002         TN  250   32000   420    31580
# 2  2004     Andhra  280   25000   850    24150
# 3  2005  Karnataka  400  650000   620   649380
# 4  2006      Bihar  360   10000   140     9860

# %%
pop_data1['expense'] = 600
pop_data1
# Out:
#    Year     States  Pop  Income  Debt  savings  expense
# 0  2001     Kerala  300   20000   320    19680      600
# 1  2002         TN  250   32000   420    31580      600
# 2  2004     Andhra  280   25000   850    24150      600
# 3  2005  Karnataka  400  650000   620   649380      600
# 4  2006      Bihar  360   10000   140     9860      600

# %%
del pop_data1['Year']
pop_data1
# Out:
#       States  Pop  Income  Debt  savings  expense
# 0     Kerala  300   20000   320    19680      600
# 1         TN  250   32000   420    31580      600
# 2     Andhra  280   25000   850    24150      600
# 3  Karnataka  400  650000   620   649380      600
# 4      Bihar  360   10000   140     9860      600

# %%
pop_data1.drop(4)
# Out:
#       States  Pop  Income  Debt  savings  expense
# 0     Kerala  300   20000   320    19680      600
# 1         TN  250   32000   420    31580      600
# 2     Andhra  280   25000   850    24150      600
# 3  Karnataka  400  650000   620   649380      600

# %%
pop_data1.drop('expense',axis=1)
# Out:
#       States  Pop  Income  Debt  savings
# 0     Kerala  300   20000   320    19680
# 1         TN  250   32000   420    31580
# 2     Andhra  280   25000   850    24150
# 3  Karnataka  400  650000   620   649380
# 4      Bihar  360   10000   140     9860

# %%
pop_data1.ndim
# Out:
# 2

# %%
pop_data1.size
# Out:
# 30

# %%
pop_data1.shape
# Out:
# (5, 6)

# %%
pop_data1
# Out:
#       States  Pop  Income  Debt  savings  expense
# 0     Kerala  300   20000   320    19680      600
# 1         TN  250   32000   420    31580      600
# 2     Andhra  280   25000   850    24150      600
# 3  Karnataka  400  650000   620   649380      600
# 4      Bihar  360   10000   140     9860      600

# %%
pop_data2 = pop_data1.drop('expense',axis=1)
pop_data2
# Out:
#       States  Pop  Income  Debt  savings
# 0     Kerala  300   20000   320    19680
# 1         TN  250   32000   420    31580
# 2     Andhra  280   25000   850    24150
# 3  Karnataka  400  650000   620   649380
# 4      Bihar  360   10000   140     9860

# %%
pop_data1
# Out:
#       States  Pop  Income  Debt  savings  expense
# 0     Kerala  300   20000   320    19680      600
# 1         TN  250   32000   420    31580      600
# 2     Andhra  280   25000   850    24150      600
# 3  Karnataka  400  650000   620   649380      600
# 4      Bihar  360   10000   140     9860      600

# %%
pop_data1.drop('expense',axis=1,inplace=True)
pop_data1
# Out:
#       States  Pop  Income  Debt  savings
# 0     Kerala  300   20000   320    19680
# 1         TN  250   32000   420    31580
# 2     Andhra  280   25000   850    24150
# 3  Karnataka  400  650000   620   649380
# 4      Bihar  360   10000   140     9860

# %%
pop_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   States   5 non-null      object
#  1   Pop      5 non-null      int64
#  2   Income   5 non-null      int64
#  3   Debt     5 non-null      int64
#  4   savings  5 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 328.0+ bytes

# %%
pop_data1.columns
# Out:
# Index(['States', 'Pop', 'Income', 'Debt', 'savings'], dtype='object')

# %%
pop_data1.dtypes
# Out:
# States     object
# Pop         int64
# Income      int64
# Debt        int64
# savings     int64
# dtype: object

# %%
pop_data1.describe()
# Out:
#               Pop         Income        Debt        savings
# count    5.000000       5.000000    5.000000       5.000000
# mean   318.000000  147400.000000  470.000000  146930.000000
# std     60.991803  281076.146266  274.226184  280988.122881
# min    250.000000   10000.000000  140.000000    9860.000000
# 25%    280.000000   20000.000000  320.000000   19680.000000
# 50%    300.000000   25000.000000  420.000000   24150.000000
# 75%    360.000000   32000.000000  620.000000   31580.000000
# max    400.000000  650000.000000  850.000000  649380.000000

# %%
pop_data1.isnull().sum()
# Out:
# States     0
# Pop        0
# Income     0
# Debt       0
# savings    0
# dtype: int64

# %%
pop_data1.nunique()
# Out:
# States     5
# Pop        5
# Income     5
# Debt       5
# savings    5
# dtype: int64

# %%
pop_data1['States'].nunique()
# Out:
# 5

# %%
pop_data1['States'].unique()
# Out:
# array(['Kerala', 'TN', 'Andhra', 'Karnataka', 'Bihar'], dtype=object)

# %%
pop_data1['States'].value_counts()
# Out:
# Kerala       1
# TN           1
# Andhra       1
# Karnataka    1
# Bihar        1
# Name: States, dtype: int64

# %%
data = pd.read_csv('/content/auto-mpg.csv')
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.shape
# Out:
# (398, 9)

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.mean()
# Out:
# <ipython-input-77-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64

# %%
data.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
data['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
data['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
data['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
data['mpg'].mean()
# Out:
# 23.514572864321607

# %%
data.groupby('origin')['mpg'].mean()
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %%
data.iloc[100:110,[0,2,5]]
# Out:
#       mpg  displacement  acceleration
# 100  18.0         250.0          16.5
# 101  23.0         198.0          16.0
# 102  26.0          97.0          21.0
# 103  11.0         400.0          14.0
# 104  12.0         400.0          12.5
# 105  13.0         360.0          13.0
# 106  12.0         350.0          12.5
# 107  18.0         232.0          15.0
# 108  20.0          97.0          19.0
# 109  21.0         140.0          19.5

# %%
data.iloc[200:210,:4]
# Out:
#       mpg  cylinders  displacement horsepower
# 200  18.0          6         250.0         78
# 201  18.5          6         250.0        110
# 202  17.5          6         258.0         95
# 203  29.5          4          97.0         71
# 204  32.0          4          85.0         70
# 205  28.0          4          97.0         75
# 206  26.5          4         140.0         72
# 207  20.0          4         130.0        102
# 208  13.0          8         318.0        150
# 209  19.0          4         120.0         88
